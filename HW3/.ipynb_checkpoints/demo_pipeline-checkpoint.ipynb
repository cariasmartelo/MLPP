# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pipeline as ppln
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
params = {
    'days': 60,
}
outcome_var = "funded_in_{}_days".format(params['days'])

# %%
projects_df = ppln.load_from_csv('projects_2012_2013.csv')
projects_df = ppln.create_outcome_var(projects_df, 60)
projects_gdf = ppln.convert_to_geopandas(projects_df)
us_gdf = ppln.load_us_map('us_shapefile/states.shp')

# %%
ppln.see_histograms(projects_df, [outcome_var])
# Out:
# funded_in_60_days
# a plott

# %%
ppln.summary_by_var(projects_df, outcome_var)
# Out:
# funded_in_60_days                                0           1  perc diff
# school_latitude                          36.329573   37.028738   1.924505
# school_longitude                        -95.947698  -95.823519  -0.129424
# school_charter                            0.085504    0.096183  12.489219
# school_magnet                             0.078200    0.088652  13.364805
# total_price_including_optional_support  801.572199  594.285067 -25.860070
# students_reached                         98.604640   94.167317  -4.500116
# eligible_double_your_impact_match         0.225271    0.325709  44.585432
# days_untill_funded                       92.488003   30.484567 -67.039436

# %%
ppln.map_projects(projects_gdf, us_gdf, outcome_var)

# %%
ppln.map_projects(projects_gdf, us_gdf, outcome_var, dense=False)

# %%
to_dummy = ['school_state', 'school_metro', 'teacher_prefix', 'primary_focus_subject',
            'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area',
            'resource_type', 'poverty_level', 'grade_level']
projects_df_discrete = ppln.make_dummies_from_categorical(projects_df, to_dummy)
projects_df_discrete = ppln.delete_columns(projects_df_discrete, to_dummy)

# %%
projects_df_discrete.columns
# Out:
# Index(['projectid', 'teacher_acctid', 'schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_district',
#        'school_county', 'school_charter',
#        ...
#        'resource_type_Trips', 'resource_type_Visitors',
#        'poverty_level_high poverty', 'poverty_level_highest poverty',
#        'poverty_level_low poverty', 'poverty_level_moderate poverty',
#        'grade_level_Grades 3-5', 'grade_level_Grades 6-8',
#        'grade_level_Grades 9-12', 'grade_level_Grades PreK-2'],
#       dtype='object', length=158)

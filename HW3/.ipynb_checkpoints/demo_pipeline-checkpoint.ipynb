# %% [markdown]
# # Homework 3
# ## Improved pipeline with different classifiers and evaluation metrics
# Machine Learning for Public Policy
#
# Camilo Arias
#
# - load, clean and transform functions in pipeline.py
#
# - classifiers in classifiers.py

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pipeline as ppln
import classifiers as classif
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ### Initial parameters of the program

# %%
params = {
    'days': 60,
    'test_size': 0.3,
    'work_with_sample': 0.1,
    'seed': 1234,
    'threshold': [0.4, 0.5, 0.6, 0.7, 0.8],
    'KNN': {'k': range(2, 11, 2),
            'weights': ['uniform', 'distance'],
            'metric': ['euclidean', 'manhattan', 'minkowsky']},

    'decision_tree': {'criterion': ['gini', 'entropy'],
                      'max_depth': [10, 15, 20, 25, 30, 35, 40]},

    'logistic_reg': {'C': [10**-2, 10**-1, 1 , 10, 10**2],
                     'penalties': ['l1', 'l2'],
                     'fit_intercept': [True, False]},

    'svm': {'C': [10**-2, 10**-1, 1 , 10, 10**2]},

    'random_forest': {'criterion': ['gini', 'entropy'],
                      'max_depth': [5, 10, 15],
                      'n_estimators': [80, 90, 100, 150]},

    'gradient_boost': {'max_depth': [5, 10, 15],
                       'n_estimators': [80, 90, 100, 150],
                       'loss': ['deviance', 'exponential']}            
}
outcome_var = "not_funded_in_{}_days".format(params['days'])

# %% [markdown]
# ### Load data and see descriptive statistics

# %%
projects_df = ppln.load_from_csv('projects_2012_2013.csv')
projects_df = ppln.create_outcome_var(projects_df, params['days'])
projects_gdf = ppln.convert_to_geopandas(projects_df)
us_gdf = ppln.load_us_map('us_shapefile/states.shp')

# %%
projects_df[outcome_var].value_counts() / len(projects_df)
# Out:
# 0    0.711865
# 1    0.288135
# Name: not_funded_in_60_days, dtype: float64

# %%
ppln.see_histograms(projects_df)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
ppln.summary_by_var(projects_df, outcome_var)
# Out:
# not_funded_in_60_days                            0           1   perc diff
# school_latitude                          37.028738   36.329573   -1.888167
# school_longitude                        -95.823519  -95.947698    0.129591
# school_charter                            0.096183    0.085504  -11.102592
# school_magnet                             0.088652    0.078200  -11.789202
# total_price_including_optional_support  594.285067  801.572199   34.880084
# students_reached                         94.167317   98.604640    4.712169
# eligible_double_your_impact_match         0.325709    0.225271  -30.836739
# days_untill_funded                       30.484567   92.488003  203.392871

# %%
ppln.map_projects(projects_gdf, us_gdf, outcome_var)

# %%
ppln.map_projects(projects_gdf, us_gdf, outcome_var, dense=False)

# %% [markdown]
# ### Converting data to dummies

# %%
initial_length = projects_df.shape[1]
to_discrete = ['total_price_including_optional_support', 'students_reached']
to_dummy = ['school_state', 'school_metro', 'teacher_prefix', 'primary_focus_subject',
            'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area',
            'resource_type', 'poverty_level', 'grade_level', 'total_price_including_optional_support',
            'students_reached']
for col in to_discrete:
    projects_df[col] = ppln.discretize(projects_df[col], 4, string=True)
projects_df = ppln.make_dummies_from_categorical(projects_df, to_dummy)

# %% [markdown]
# ### Working only with a sample

# %%
if params['work_with_sample']:
    projects_df = projects_df.sample(frac=params['work_with_sample'], random_state=params['seed'])

# %%
projects_df.shape
# Out:
# (1250, 165)

# %%
features = list(projects_df.columns[initial_length - len(to_dummy):]) #Get only new dummies
features += ['school_charter', 'school_magnet', 'eligible_double_your_impact_match']
y = projects_df[outcome_var]
x = projects_df[features]

# %% [markdown]
# #### Spliting data intro train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=params['test_size'])

# %% [markdown]
# ##  KNN model with one set of parameters

# %%
knn = classif.build_knn(y_train, x_train,
                        k=params['KNN']['k'][0],
                        weights=params['KNN']['weights'][0],
                        metric=params['KNN']['metric'][0])
y_prob = classif.predict_proba(knn, x_test)

# %%
y_prob.hist()

# %%
y_pred = classif.classify(y_prob, params['threshold'][-1])

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[2456,  245],
#        [ 898,  151]])

# %%
y_pred = classif.classify(y_prob, 0.7)

# %%
classif.build_evaluation_metrics(y_test, y_pred, y_prob)
# Out:
# {'precision': 0.6952,
#  'recall': 0.6952,
#  'f1': 0.6952,
#  'accuracy': 0.6952,
#  'roc auc': 0.5629971810744105}

# %%
classif.plot_precision_recall(y_test, y_prob)

# %%
y_test.values.reshape((1, -1))
# Out:
# array([[1, 1, 0, ..., 0, 0, 0]])

# %%
target_names = ['class 0', 'class 1']
report_dict = classif.classification_report(y_test, y_pred, output_dict = True)

# %%
classif.plot_precision_recall(y_test, y_prob, x_axis='recall')

# %% [markdown]
# ##  DT model with one set of parameters

# %%
report_dict['micro avg']
# Out:
# {'precision': 0.664, 'recall': 0.664, 'f1-score': 0.664, 'support': 375}

# %%
tree = classif.build_tree(y_train, x_train,
                          max_depth=params['decision_tree']['max_depth'][0],
                          criterion=params['decision_tree']['criterion'][0])
y_prob = classif.predict_proba(tree, x_test)

# %%
y_prob.hist()

# %%
y_pred = classif.classify(y_prob,
                          params['threshold'][2])

# %%
y_pred.mean()
# Out:
# 0.192

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[229,  49],
#        [ 74,  23]])

# %%
classif.build_evaluation_metrics(y_test, y_pred, y_prob)
# Out:
# {'precision': 0.3194444444444444,
#  'recall': 0.23711340206185566,
#  'f1': 0.272189349112426,
#  'accuracy': 0.672,
#  'roc auc': 0.5901320180968628}

# %%
classif.plot_precision_recall(y_test, y_prob)

# %%
classif.plot_precision_recall(y_test, y_prob, x_axis='recall')

# %% [markdown]
# ##  Logistic Regression model with one set of parameters

# %%
lrf = classif.build_logistic_reg(y_train, x_train,
                    C=params['logistic_reg']['C'][2],
                    penalty=params['logistic_reg']['penalties'][-1],
                    fit_intercept=params['logistic_reg']['fit_intercept'][0],
                    seed = params['seed'])
y_prob = classif.predict_proba(lrf, x_test)

# %%
y_prob.hist()

# %%
y_pred = classif.classify(y_prob,
                          params['threshold'][2])

# %%
y_pred.mean()
# Out:
# 0.072

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[265,  13],
#        [ 83,  14]])

# %%
classif.build_evaluation_metrics(y_test, y_pred, y_prob)
# Out:
# {'precision': 0.5185185185185185,
#  'recall': 0.14432989690721648,
#  'f1': 0.2258064516129032,
#  'accuracy': 0.744,
#  'roc auc': 0.6725877030334495}

# %%
classif.plot_precision_recall(y_test, y_prob)

# %%
classif.plot_precision_recall(y_test, y_prob, x_axis='recall')

# %% [markdown]
# ##  SVM model with one set of parameters

# %%
svc = classif.build_svm(y_train, x_train,
                    C=params['svm']['C'][2],
                    seed = params['seed'])
confidence_score = svc.decision_function(x_test)

# %%
confidence_score.min()
# Out:
# -1.890739358278641

# %%
y_pred =  np.array([1 if x > 0 else 0 for x in confidence_score])

# %%
y_pred.mean()
# Out:
# 0.176

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[246,  32],
#        [ 63,  34]])

# %%
classif.build_evaluation_metrics(y_test, y_pred, confidence_score)
# Out:
# {'precision': 0.5151515151515151,
#  'recall': 0.35051546391752575,
#  'f1': 0.4171779141104294,
#  'accuracy': 0.7466666666666667,
#  'roc auc': 0.6626863457687457}

# %% [markdown]
# ##  Random Forest model with one set of parameters

# %%
forest = classif.build_random_forest(
    y_train, x_train,
    max_depth=params['random_forest']['max_depth'][-1],
    criterion=params['random_forest']['criterion'][1],
    n_estimators=params['random_forest']['n_estimators'][3],
    seed=params['seed'])
y_prob = classif.predict_proba(forest, x_test)

# %%
y_prob.hist()

# %%
y_pred = classif.classify(y_prob,
                          params['threshold'][0])

# %%
y_pred.mean()
# Out:
# 0.22666666666666666

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[229,  49],
#        [ 61,  36]])

# %%
classif.build_evaluation_metrics(y_test, y_pred, y_prob)
# Out:
# {'precision': 0.4235294117647059,
#  'recall': 0.3711340206185567,
#  'f1': 0.3956043956043956,
#  'accuracy': 0.7066666666666667,
#  'roc auc': 0.6713639397760143}

# %%
classif.plot_precision_recall(y_test, y_prob)

# %%
classif.plot_precision_recall(y_test, y_prob, x_axis='recall')

# %% [markdown]
# ##  Gradient Boost model with one set of parameters

# %%
gb = classif.build_gradient_boost(
    y_train, x_train,
    max_depth=params['gradient_boost']['max_depth'][-1],
    n_estimators=params['gradient_boost']['n_estimators'][3],
    loss=params['gradient_boost']['loss'][0],
    seed=params['seed'])
y_prob = classif.predict_proba(gb, x_test)

# %%
y_prob.hist()

# %%
y_pred = classif.classify(y_prob,
                          params['threshold'][-2])

# %%
y_pred.mean()
# Out:
# 0.15466666666666667

# %%
classif.confusion_matrix(y_test, y_pred)
# Out:
# array([[243,  35],
#        [ 74,  23]])

# %%
classif.build_evaluation_metrics(y_test, y_pred, y_prob)
# Out:
# {'precision': 0.39655172413793105,
#  'recall': 0.23711340206185566,
#  'f1': 0.2967741935483871,
#  'accuracy': 0.7093333333333334,
#  'roc auc': 0.6470370095676037}

# %%
classif.plot_precision_recall(y_test, y_prob)

# %%
classif.plot_precision_recall(y_test, y_prob, x_axis='recall')
